# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame, Panel
import csv
import matplotlib.pyplot as plt
from collections import Counter
import sklearn
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import log_loss
import datetime
from random import random
from collections import defaultdict
from numpy import isnan
import numpy
import operator
from scipy import spatial
from operator import truediv
from pylab import *

# %%
fig,ax2 = plt.subplots(ncols=1)
y = np.array([0.35,0.45,0.44,0.34,0.58,0.2,0.47,0.16,0.46,0.62,0.5])
x = np.array([227,1243,337,262,1853,415,393,253,503,215,794])
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


ax2.plot(x_ordered, y_ordered, marker="o", markerfacecolor="navy")
plt.xlabel('The number of test Front Page')
plt.ylabel('The improvement of MAP')
plt.axis([100, 2000, 0, 0.8])
plt.savefig('map1.png',api = 400)
plt.show()

# %%
fig,ax2 = plt.subplots(ncols=1)
y = np.array([0.35,0.45,0.44,0.34,0.58,0.2,0.47,0.16,0.46,0.62,0.5])
x = np.array([1342,7879,1539,3493,9543,2359,2529,1711,2524,1731,5136])
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


ax2.plot(x_ordered, y_ordered, marker="o", markerfacecolor="navy")
plt.xlabel('The number of train Front Page')
plt.ylabel('The improvement of MAP')
plt.savefig('map2.png',api = 400)

plt.show()

# %%
fig,ax2 = plt.subplots(ncols=1)
y = np.array([0.35,0.45,0.44,0.34,0.58,0.2,0.47,0.16,0.46,0.62,0.5])
x = np.array([0.05,0.02,0.07,0.02,0.05,0.03,0.04,0.03,0.04,0.03])
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


ax2.plot(x_ordered, y_ordered, marker="o", markerfacecolor="navy")
plt.xlabel('CTR of training Front Page')
plt.ylabel('The improvement of MAP')

plt.axis([0.01, 0.08, 0, 1])
plt.savefig('map3.png',api = 400)
plt.show()

# %% [markdown]
# ### improved ctr

# %%
fig,ax2 = plt.subplots(ncols=1)
y = np.array([0.784,1.22,2.9,0.29,0.14,1.45,2.16,1.24,0.86,0.84,2.7])
x = np.array([227,1243,337,262,1853,415,393,253,503,215,794])
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


ax2.plot(x_ordered, y_ordered, marker="o", markerfacecolor="navy")
plt.xlabel('The number of test Front Page')
plt.ylabel('The improvement of CTR unser simulation evironment')
plt.axis([100, 2000, 0, 3])
plt.savefig('ctr1.png',api = 400)
plt.show()

# %%
fig,ax2 = plt.subplots(ncols=1)
y = np.array([0.784,1.22,2.9,0.29,0.14,1.45,2.16,1.24,0.86,0.84,2.7])
x = np.array([1342,7879,1539,3493,9543,2359,2529,1711,2524,1731,5136])
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


ax2.plot(x_ordered, y_ordered, marker="o", markerfacecolor="navy")
plt.xlabel('The number of train Front Page')
plt.ylabel('The improvement of CTR unser simulation evironment')

plt.savefig('ctr2.png',api = 400)
plt.show()

# %%
fig,ax2 = plt.subplots(ncols=1)
y = np.array([0.784,1.22,2.9,0.29,0.14,1.45,2.16,1.24,0.86,0.84,2.7])
x = np.array([0.05,0.02,0.07,0.02,0.05,0.03,0.04,0.03,0.04,0.03])
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


ax2.plot(x_ordered, y_ordered, marker="o", markerfacecolor="navy")
plt.xlabel('CTR of training Front Page')
plt.ylabel('The improvement of CTR unser simulation evironment')

plt.axis([0, 0.1, 0, 3])
plt.savefig('ctr3.png',api = 400)
plt.show()

# %% [markdown]
# ### user fatigue

# %%
plt.figure()
y = np.array([4,7,4,2,6,7,7,7,4,4,4,6,6,6,5,4,6,5,6,4])
y_1 = np.array([5,12,5,2,9,15,9,12,9,4,4,10,7,10,6,7,9,5,6,5])
x = np.array(np.arange(20))
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


plt.plot(x, y,'g--o',
         label='New-FrontPage',
         color='deeppink', linewidth=1)
plt.plot(x, y_1,'r-o',
         label='Old-FrontPage',
         color='blue', linewidth=1)

plt.axis([-1, 20, 0, 20])
plt.xlabel('The index of different user group')
plt.ylabel('The max number of similar news frequency')
#plt.title("The evaluation of user fatigue")
plt.legend()
plt.savefig('user1.png',api = 400)
plt.show()

# %% [markdown]
# ### comparision

# %%
plt.figure()
y = np.array([-0.03,0.55,0.19,0.42])
y_1 = np.array([0.47,0.77,0.76,0.86])
y_2 = np.array([-0.15,0.32,0.02,0.37])
x = np.array(np.arange(1,5))
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


plt.plot(x, y,'g--o',
         label='epsilon-greedy with linear(e = 0.01)',
         color='deeppink', linewidth=1)
plt.plot(x, y_1,'r-o',
         label='CCM Bandit',
         color='blue', linewidth=1)
plt.plot(x, y_2,'rs--',
         label='epsilon-greedy(e = 0.01)',
         color='navy', linewidth=1)

plt.axis([0, 5, -0.4, 1.2])
plt.xlabel('The index of different user group')
plt.ylabel('The improvement of CTR under simulation environment')
#plt.title("The evaluation of user fatigue")
plt.legend()
plt.savefig('comp1.png',api = 400)
plt.show()

# %% [markdown]
# ### OVERALL MAP

# %%
plt.figure()
y = np.array([0.1235,0.4316,0.1406,0.1314,0.1833,0.12329,0.2083,0.1273,0.1122,0.1004,0.1268,0.2105,0.1546,0.1479,0.2616,0.1429,0.1125,0.142,0.1843,0.1802])
y_1 = np.array([0.1556,0.5704,0.1959,0.2064,0.2162,0.187,0.2722,0.1909,0.172,0.1722,0.1956,0.2988,0.2269,0.2547,0.3294,0.2279,0.1788,0.196,0.2296,0.2354])
y_2 = np.array([0.26,0.32,0.39,0.57,0.18,0.52,0.31,0.5,0.53,0.72,0.54,0.42,0.47,0.42,0.26,0.59,0.59,0.38,0.25,0.31])
x = np.array(np.arange(1,21))
indexs_to_order_by = x.argsort()
x_ordered = x[indexs_to_order_by]
y_ordered = y[indexs_to_order_by]


plt.plot(x, y,'g--o',
         label='MAP of true test Front Page',
         color='deeppink', linewidth=1)
plt.plot(x, y_1,'r-o',
         label='MAP of generated test Front Page',
         color='blue', linewidth=1)
plt.plot(x, y_2,'rs--',
         label='Improvement of MAP',
         color='navy', linewidth=1)

plt.axis([0, 21, 0, 1.2])
plt.xlabel('The index of different user group')
plt.ylabel('MAP')
#plt.title("The evaluation of user fatigue")
plt.legend()
plt.savefig('maptotal.png',api = 400)
plt.show()
